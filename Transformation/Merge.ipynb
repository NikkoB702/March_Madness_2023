# %%
import pandas as pd

# %%
df1 = pd.read_csv("C:/Users/Home/March_Madness_2023/Data/clean_Data.csv")
df2 = pd.read_csv("C:/Users/Home/March_Madness_2023/Data/cbb_clean_Data.csv")

df = pd.merge(df1,df2, on='Team', how='outer')

# %%
df
# Out:
#        Rk                 Team    Conf_x     W-L  BPI Off  BPI Def   BPI  \
# 0       1               Kansas    Big 12    37-3     12.4      9.6  21.9
# 1       1               Kansas    Big 12    37-3     12.4      9.6  21.9
# 2       1               Kansas    Big 12    37-3     12.4      9.6  21.9
# 3       1               Kansas    Big 12    37-3     12.4      9.6  21.9
# 4       1               Kansas    Big 12    37-3     12.4      9.6  21.9
# ...   ...                  ...       ...     ...      ...      ...   ...
# 4702  270  Louisiana Lafayette  Sun Belt  20-Nov      1.1     -6.3  -5.2
# 4703  270  Louisiana Lafayette  Sun Belt  20-Nov      1.1     -6.3  -5.2
# 4704  270  Louisiana Lafayette  Sun Belt  20-Nov      1.1     -6.3  -5.2
# 4705  270  Louisiana Lafayette  Sun Belt  20-Nov      1.1     -6.3  -5.2
# 4706  270  Louisiana Lafayette  Sun Belt  20-Nov      1.1     -6.3  -5.2
#
#       Year_x Conf_y  ADJOE  ...   DRB   FTR  FTRD  2P_O  2P_D  3P_O  3P_D  \
# ...

# %%
df['Team'].value_counts()
# Out:
# Kansas                 77
# Arizona St.            77
# Memphis                77
# Creighton              77
# Alabama                77
#                        ..
# Northern Kentucky      42
# Grand Canyon           30
# Texas A&M-CC           11
# SE Missouri St.        11
# Louisiana Lafayette     7
# Name: Team, Length: 65, dtype: int64

# %%
df['Team'].unique()
# Out:
# array(['Kansas', 'Memphis', 'UCLA', 'Duke', 'West Virginia', 'Tennessee',
#        'Xavier', 'Marquette', 'Texas', 'Michigan St.', 'Pittsburgh',
#        'Indiana', 'Connecticut', 'Texas A&M', 'USC', 'Gonzaga',
#        'Mississippi St.', 'Arizona', 'Miami FL', 'Drake', 'Purdue',
#        'Arkansas', 'Kansas St.', 'Missouri', 'VCU', 'Maryland',
#        'Illinois', 'Baylor', 'Kent St.', 'Kentucky', 'Arizona St.',
#        'Houston', 'Virginia', 'Creighton', 'Alabama', 'Providence',
#        'Oral Roberts', 'UC Santa Barbara', 'San Diego St.',
#        'North Carolina St.', 'Nevada', 'Auburn', 'Utah St.', 'Iowa St.',
#        'UNC Asheville', 'Vermont', 'Iowa', 'College of Charleston', 'TCU',
#        'Colgate', 'Northwestern', 'Florida Atlantic', 'Montana St.',
#        'Iona', 'Texas A&M-CC', 'Princeton', 'Furman', 'SE Missouri St.',
#        'Kennesaw St.', 'Fairleigh Dickinson', 'Texas Southern', 'Howard',
#        'Northern Kentucky', 'Grand Canyon', 'Louisiana Lafayette'],
# ...

# %%
df.shape
# Out:
# (4707, 27)

# %%
df.isna().sum()
# Out:
# Rk          0
# Team        0
# Conf_x      0
# W-L         0
# BPI Off     0
# BPI Def     0
# BPI         0
# Year_x      0
# Conf_y     22
# ADJOE      22
# ADJDE      22
# BARTHAG    22
# EFG_O      22
# EFG_D      22
# TOR        22
# TORD       22
# ORB        22
# DRB        22
# FTR        22
# FTRD       22
# 2P_O       22
# 2P_D       22
# 3P_O       22
# 3P_D       22
# ADJ_T      22
# WAB        22
# Year_y     22
# dtype: int64

# %%
df.describe()
# Out:
#                 Rk      BPI Off      BPI Def          BPI       Year_x  \
# count  4707.000000  4707.000000  4707.000000  4707.000000  4707.000000
# mean    104.084342     3.205949     2.441640     5.647504  2013.028043
# std      94.496770     5.397369     4.466254     7.825622     3.153136
# min       1.000000   -14.900000   -12.300000   -15.900000  2008.000000
# 25%      28.000000    -0.300000    -0.600000     0.900000  2010.000000
# 50%      72.000000     3.700000     2.800000     6.700000  2013.000000
# 75%     153.000000     7.000000     5.500000    11.200000  2016.000000
# max     346.000000    16.400000    17.700000    23.900000  2018.000000
#
#             ADJOE        ADJDE      BARTHAG        EFG_O        EFG_D  ...  \
# count  4685.00000  4685.000000  4685.000000  4685.000000  4685.000000  ...
# mean    108.71063    99.308666     0.690495    50.902476    48.666403  ...
# std       7.47350     6.378898     0.239448     3.216986     2.778850  ...
# ...

# %%
df.dtypes
# Out:
# Rk           int64
# Team        object
# Conf_x      object
# W-L         object
# BPI Off    float64
# BPI Def    float64
# BPI        float64
# Year_x       int64
# Conf_y      object
# ADJOE      float64
# ADJDE      float64
# BARTHAG    float64
# EFG_O      float64
# EFG_D      float64
# TOR        float64
# TORD       float64
# ORB        float64
# DRB        float64
# FTR        float64
# FTRD       float64
# 2P_O       float64
# 2P_D       float64
# 3P_O       float64
# 3P_D       float64
# ADJ_T      float64
# WAB        float64
# Year_y     float64
# dtype: object

# %%
clean_df = df.drop(['Conf_y','W','POSTSEASON','SEED'], axis=1)
clean_df.head()

# %%
# clean_df.to_csv('C:/Users/Home/March_Madness_2023/Data/cbb_clean_merge_Data.csv', index = False)
