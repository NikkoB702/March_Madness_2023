# %%
import pandas as pd

# %%
cbb_df = pd.read_csv('C:/Users/Home/March_Madness_2023/Data/ESPN_BPI.csv')
cbb_df
# Out:
#        Rk                    Team    Conf     W-L  BPI Off  BPI Def   BPI  \
# 0       1                  Kansas  Big 12    37-3     12.4      9.6  21.9
# 1       2          North Carolina     ACC    36-3     19.2      1.0  20.2
# 2       3                 Memphis   C-USA    38-2     11.3      8.0  19.3
# 3       4                    UCLA  Pac-12    35-4      7.9     10.9  18.9
# 4       5                    Duke     ACC    28-6     13.8      4.3  18.2
# ...   ...                     ...     ...     ...      ...      ...   ...
# 3814  347  Mississippi Valley St.    SWAC  28-Apr     -9.9     -6.5 -16.3
# 3815  348             Chicago St.     WAC  29-Mar     -7.5     -9.0 -16.5
# 3816  349            Delaware St.    MEAC  28-Apr     -9.4     -8.5 -18.0
# 3817  350             Alabama A&M    SWAC  28-Mar    -11.7     -7.4 -19.1
# 3818  351  Maryland-Eastern Shore    MEAC  25-Jul    -10.1     -9.5 -19.6
#
#       Year
# 0     2008
# 1     2008
# 2     2008
# 3     2008
# 4     2008
# ...

# %%
cbb_df['Team'].unique()
# Out:
# array(['Kansas', 'North Carolina', 'Memphis', 'UCLA', 'Duke',
#        'Georgetown', 'West Virginia', 'Wisconsin', 'Tennessee',
#        'Louisville', 'Davidson', 'Clemson', 'Washington St.', 'Xavier',
#        'Marquette', 'Stanford', 'Texas', 'Michigan St.', 'Pittsburgh',
#        'Indiana', 'Butler', 'Connecticut', 'Texas A&M', 'Notre Dame',
#        'USC', 'Ohio St.', 'Gonzaga', 'Mississippi St.', 'Arizona',
#        'Florida', 'Miami FL', 'Drake', 'Purdue', 'Oregon',
#        'Virginia Tech', 'Arkansas', 'Kansas St.', 'Syracuse', 'Oklahoma',
#        "Saint Joseph's", 'Mississippi', 'New Mexico', 'Georgia Tech',
#        'Missouri', 'Villanova', 'VCU', "Saint Mary's", 'UNLV',
#        'Vanderbilt', 'Maryland', 'Florida St.', 'BYU', 'Western Kentucky',
#        'Illinois', 'Rhode Island', 'Baylor', 'Massachusetts', 'Minnesota',
#        'Kent St.', 'Nebraska', 'Duquesne', 'Kentucky', 'Arizona St.',
#        'Dayton', 'Wake Forest', 'Temple', 'Washington', 'California',
# ...

# %%
cbb_df['Conf'].unique()
# Out:
# array(['Big 12', 'ACC', 'C-USA', 'Pac-12', 'Big East', 'Big Ten', 'SEC',
#        'Southern', 'A 10', 'Horizon', 'WCC', 'MVC', 'MW', 'CAA',
#        'Sun Belt', 'MAC E', 'Summit', 'Big South', 'MAAC', 'Southland',
#        'Big West', 'MAC W', 'WAC', 'Ivy', 'Big Sky', 'NEC', 'A-Sun',
#        'Am. East', 'OVC', 'Patriot', 'MEAC', 'Indep.', 'SWAC',
#        'Ohio Valley E', 'Ohio Valley W', 'Big South S', 'Big South N',
#        'American'], dtype=object)

# %%
final_df = cbb_df[cbb_df['Team'].isin(['Purdue','Texas Southern','Fairleigh Dickinson','Memphis','Florida Atlantic','Duke','Oral Roberts','Tennessee','Louisiana Lafayette','Kentucky','Providence','Kansas St.','Montana St.','Michigan St.','USC','Marquette','Vermont','Kansas','Howard','Arkansas','Illinois','Saint Mary','VCU','Connecticut','Iona','TCU','Arizona St.','Nevada','Gonzaga','Grand Canyon','Northwestern','Boise State','UCLA','UNC Asheville','Houston','Northern Kentucky','Iowa','Auburn','Miami FL','Drake','Indiana','Kent St.','Iowa St.','Mississippi St.','Pittsburgh','Xavier','Kennesaw St.','Texas A&M','Penn State','Texas','Colgate','Alabama','Texas A&M-CC','SE Missouri St.','Maryland','West Virginia','San Diego St.','College of Charleston','Virginia','Furman','Creighton','North Carolina St.','Baylor','UC Santa Barbara','Missouri','Utah St.','Arizona','Princeton'])]
final_df.head()
# Out:
#    Rk           Team      Conf    W-L  BPI Off  BPI Def   BPI  Year
# 0   1         Kansas    Big 12   37-3     12.4      9.6  21.9  2008
# 2   3        Memphis     C-USA   38-2     11.3      8.0  19.3  2008
# 3   4           UCLA    Pac-12   35-4      7.9     10.9  18.9  2008
# 4   5           Duke       ACC   28-6     13.8      4.3  18.2  2008
# 6   7  West Virginia  Big East  26-11      8.9      7.7  16.6  2008

# %%
final_df['Team'].unique()
# Out:
# array(['Kansas', 'Memphis', 'UCLA', 'Duke', 'West Virginia', 'Tennessee',
#        'Xavier', 'Marquette', 'Texas', 'Michigan St.', 'Pittsburgh',
#        'Indiana', 'Connecticut', 'Texas A&M', 'USC', 'Gonzaga',
#        'Mississippi St.', 'Arizona', 'Miami FL', 'Drake', 'Purdue',
#        'Arkansas', 'Kansas St.', 'Missouri', 'VCU', 'Maryland',
#        'Illinois', 'Baylor', 'Kent St.', 'Kentucky', 'Arizona St.',
#        'Houston', 'Virginia', 'Creighton', 'Alabama', 'Providence',
#        'Oral Roberts', 'UC Santa Barbara', 'San Diego St.',
#        'North Carolina St.', 'Nevada', 'Auburn', 'Utah St.', 'Iowa St.',
#        'UNC Asheville', 'Vermont', 'Iowa', 'College of Charleston', 'TCU',
#        'Colgate', 'Northwestern', 'Florida Atlantic', 'Montana St.',
#        'Iona', 'Texas A&M-CC', 'Princeton', 'Furman', 'SE Missouri St.',
#        'Kennesaw St.', 'Fairleigh Dickinson', 'Texas Southern', 'Howard',
#        'Northern Kentucky', 'Grand Canyon', 'Louisiana Lafayette'],
# ...

# %%
final_df['Team'].value_counts()
# Out:
# Kansas                   11
# College of Charleston    11
# Creighton                11
# Alabama                  11
# Providence               11
#                          ..
# North Carolina St.       10
# VCU                      10
# Northern Kentucky         6
# Grand Canyon              5
# Louisiana Lafayette       1
# Name: Team, Length: 65, dtype: int64

# %%
final_df['Team'].dtypes
# Out:
# dtype('O')

# %%
final_df.to_csv('C:/Users/Home/March_Madness_2023/Data/clean_Data.csv', index = False)
